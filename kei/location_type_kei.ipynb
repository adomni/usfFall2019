# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
billboards_data = pd.read_csv('data/billboards_20190916.csv')
billboards_data.head()
# Out:
# /Users/kei/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    id                      locationHash  networkId                     name  \
# 0  20  fe707bdee17281102dc95c9033379149          0        I-215 and Durango
# 1  21  203f5b73a45813bcd385e4bf647395b8          0          I-215 and Jones
# 2  22  90b91c6b8e1d3160c023b6a074133cad          0  I-215 and Valley View 2
# 3  23  68bac0690e1090a12ba0d398d083d3b4          0    I-15 and Warm Springs
# 4  24  25c0366830f49de9358d96a00378a3ee          0   I-15 and St. Rose Pkwy
#
#   directionId directionName          lat         lng  googlePlacesId  typeId  \
# 0           7         North  36.06556000 -115.272515   Las Vegas, NV    75.0
# 1          10          East  36.06669000 -115.215070   Las Vegas, NV    75.0
# 2          10          East  36.06770000 -115.192320   Las Vegas, NV    75.0
# 3          11         South  36.05768500 -115.179950  Enterprise, NV    75.0
# 4          12          West  35.97996000 -115.180570   Las Vegas, NV    75.0
#
#    typeName
# 0  Bulletin
# 1  Bulletin
# 2  Bulletin
# 3  Bulletin
# 4  Bulletin

# %%
len(billboards_data)
# Out:
# 93540

# %%
# multiple rows for each locationHash

# %%
billboards_data.groupby('typeName').size()
# multiple rows for each typeName
# Out:
# typeName
# Advertisers                       10
# Alcohol Store                     27
# Bar/Restaurant Jukebox         48543
# Bar/Restaurant TV                257
# Bulletin                        5532
# Bus Interior                       8
# Cinema Lobby                     898
# Coffee Shop                       11
# College Campus                   619
# DMV                               29
# Dental Clinic                    556
# Doctors Office Waiting Room    20809
# EV Kiosk                           2
# Grocery Checkout Aisle           302
# Grocery Store                     73
# Mobile Billboard                  21
# Other Indoor                      15
# Pharmacy / Drugstore              48
# Point of Sale Screen            7524
# Poster                          1187
# Rest Stop                         78
# Salon (Men)                       91
# Salon (Women)                    730
# Shopping Mall                   1740
# Shopping Mall Food Court         249
# Spectacular                       13
# Taxi Exterior                     48
# Transit Shelter                  269
# Urban Panel                      110
# dtype: int64

# %%
def isOneToOne(df, col1, col2):
    first = df.groupby(col1)[col2].count().max()
    second = df.groupby(col2)[col1].count().max()
    return first + second == 2

isOneToOne(billboards_data, 'locationHash', 'typeName')
# Out:
# False

# %%
location_audience_data = data = pd.read_csv('data/output.csv', error_bad_lines=False)
location_audience_data.head()
# Out:
# b'Skipping line 5001: expected 8 fields, saw 15\nSkipping line 10000: expected 8 fields, saw 15\nSkipping line 14999: expected 8 fields, saw 15\n'
#    uniqueDevicesAtLocation  count  dmaIndex                      locationHash  \
# 0                      366      2  1.959597  b6e71c034fa5e34b5d8a9199208d53cb
# 1                      366      1  1.364638  b6e71c034fa5e34b5d8a9199208d53cb
# 2                      366      5  2.962701  b6e71c034fa5e34b5d8a9199208d53cb
# 3                      366      1  0.959328  b6e71c034fa5e34b5d8a9199208d53cb
# 4                      366      1  0.951531  b6e71c034fa5e34b5d8a9199208d53cb
#
#    audienceSegmentId         entryType  \
# 0                  1  LOCATION_SUMMARY
# 1                  2  LOCATION_SUMMARY
# 2                  3  LOCATION_SUMMARY
# 3                  4  LOCATION_SUMMARY
# 4                  5  LOCATION_SUMMARY
#
#                                            placeIqId  dmaName
# 0  AutomotiveDealerships->Domestic->General->GMC-...      630
# 1  AutomotiveDealerships->Domestic->Luxury->GMC->...      630
# 2  AutomotiveDealerships->Domestic->General->GMC-...      630
# 3  AutomotiveDealerships->Domestic->General->Fiat...      630
# 4  AutomotiveDealerships->Domestic->General->Fiat...      630

# %%
len(location_audience_data)
# Out:
# 19994

# %%
location_audience_data.groupby('locationHash').size()
# multiple rows for each locationHash.
# Out:
# locationHash
# 0c89d6c44290bc885650a2eb4a3f480e      3
# 13151ff83caabeeecf14ee69512f70d3    623
# 19948cf2ef652334cc2d7f4609eb1f28    633
# 2a3180b90180b227db81c95b49240bd2    559
# 2ecabc7a18e9332b10bad28e75167544    598
# 387cc3a3376bedf0388698a3715ee137    736
# 3fa83a49e380c72cd6be15b29ac6e53d    297
# 4189a97e0a61cab5a19862910f6a555e    802
# 56795ff9c9d5378b4ead68c31833a406    708
# 56b704d2f77094c89a85d170b972b449    649
# 5a1308e5465bfe32d67b8171ec5a1a58    618
# 5ae370d6b68926236ba7b659dbbbf251    601
# 5de857121848bc3caa0adfed05dbe3ae    532
# 60334adaae82a1a172c3c1020dee7b07    720
# 8237da911b3dc385276efc93b19ecaad    589
# 84f6050da3b919f5f742e8d5d787a264    754
# 88cd97c420635430a6014b672d5c67b6    574
# 892ed24d6fe6b03e61e6dd441d650fac    396
# 8e068a53d42717b05eb8ae317590165f    808
# 93afb61aab2c5b09107ebc0a8c1f6fac    533
# 95d58fb689c6dbc1a71d44dcaf43aa46    409
# 9a74a7e8192188f478b3bd3b1f887a03    330
# b03a84f7ee3b2c4546e774cd36e762db    781
# b14273d2a9fb0465d2fe6a1d859e5b6d    733
# b1b16e79fd5cad106899df827e3d9d12    314
# b6e71c034fa5e34b5d8a9199208d53cb    420
# c3daa24315511ad4bbbce3d3be687908    320
# c8c505947fa572674fe920e201da1e3f    661
# c976d31ec7c1077481faa28693517ebc    796
# cbd209a58f1613278732ae88afa25c79    160
# ce68239ed83c6c1d85707fe8319a8917    578
# e139955e52f449d931cacbc773950d95    368
# e46630e498e76d2e04f2ed521f4ae35e    726
# f4a2fe3a4cc1389495d39501f88f1153    639
# f9fe2a60466142fc3666e5e20e4ca701    525
# fecaa6e724c8d218682f00e49328a173    501
# dtype: int64

# %%
location_audience_data[location_audience_data['locationHash']=="fecaa6e724c8d218682f00e49328a173"]
# Out:
#       uniqueDevicesAtLocation  count  dmaIndex  \
# 2593                      899     15  3.769179
# 2594                      899      5  1.967907
# 2595                      899     29  5.287552
# 2596                      899     14  3.241115
# 2597                      899     14  3.251203
# 2598                      899      9  2.340908
# 2599                      899     19  4.825367
# 2600                      899     12  2.870341
# 2601                      899      1  1.044565
# 2602                      899     12  2.961905
# 2603                      899      2  1.303263
# 2604                      899      2  5.803139
# 2605                      899      6  1.650182
# 2606                      899      3  1.458211
# 2607                      899      1  8.632769
# 2608                      899      6  5.013912
# 2609                      899      1  1.607023
# 2610                      899      2  3.934332
# 2611                      899      8  3.012444
# 2612                      899      1  1.284828
# 2613                      899      2  1.365445
# 2614                      899      8  1.146614
# 2615                      899      3  0.941898
# 2616                      899      2  2.244306
# 2617                      899     92  2.323611
# 2618                      899     20  3.671627
# 2619                      899    189  2.182567
# 2620                      899    265  2.084370
# 2621                      899    261  1.964947
# 2622                      899    193  2.015102
# ...                       ...    ...       ...
# 3064                      899    103  3.394762
# 3065                      899    244  2.136519
# 3066                      899     20  1.517932
# 3067                      899    270  2.403448
# 3068                      899     21  0.965657
# 3069                      899     27  2.369424
# 3070                      899     17  1.483881
# 3071                      899      2  0.691078
# 3072                      899     14  1.328480
# 3073                      899    360  2.240501
# 3074                      899    182  4.005369
# 3075                      899      1  0.978057
# 3076                      899     26  2.492767
# 3077                      899      7  1.507620
# 3078                      899      1  0.616263
# 3079                      899      4  0.499672
# 3080                      899      1  0.324904
# 3081                      899     82  1.320929
# 3082                      899      1  0.650414
# 3083                      899      3  1.465028
# 3084                      899     41  2.944257
# 3085                      899     21  1.587255
# 3086                      899      2  0.578226
# 3087                      899     15  0.863991
# 3088                      899      5  0.663384
# 3089                      899     20  1.151988
# 3090                      899     21  1.181189
# 3091                      899      4  2.406832
# 3092                      899     16  1.042025
# 3093                      899     14  1.483306
#
#                           locationHash  audienceSegmentId         entryType  \
# 2593  fecaa6e724c8d218682f00e49328a173                  1  LOCATION_SUMMARY
# 2594  fecaa6e724c8d218682f00e49328a173                  2  LOCATION_SUMMARY
# 2595  fecaa6e724c8d218682f00e49328a173                  3  LOCATION_SUMMARY
# 2596  fecaa6e724c8d218682f00e49328a173                  4  LOCATION_SUMMARY
# 2597  fecaa6e724c8d218682f00e49328a173                  5  LOCATION_SUMMARY
# 2598  fecaa6e724c8d218682f00e49328a173                  6  LOCATION_SUMMARY
# 2599  fecaa6e724c8d218682f00e49328a173                  7  LOCATION_SUMMARY
# 2600  fecaa6e724c8d218682f00e49328a173                  8  LOCATION_SUMMARY
# 2601  fecaa6e724c8d218682f00e49328a173                  9  LOCATION_SUMMARY
# 2602  fecaa6e724c8d218682f00e49328a173                 10  LOCATION_SUMMARY
# 2603  fecaa6e724c8d218682f00e49328a173                 12  LOCATION_SUMMARY
# 2604  fecaa6e724c8d218682f00e49328a173                 14  LOCATION_SUMMARY
# 2605  fecaa6e724c8d218682f00e49328a173                 17  LOCATION_SUMMARY
# 2606  fecaa6e724c8d218682f00e49328a173                 18  LOCATION_SUMMARY
# 2607  fecaa6e724c8d218682f00e49328a173                 22  LOCATION_SUMMARY
# 2608  fecaa6e724c8d218682f00e49328a173                 26  LOCATION_SUMMARY
# 2609  fecaa6e724c8d218682f00e49328a173                 27  LOCATION_SUMMARY
# 2610  fecaa6e724c8d218682f00e49328a173                 29  LOCATION_SUMMARY
# 2611  fecaa6e724c8d218682f00e49328a173                 30  LOCATION_SUMMARY
# 2612  fecaa6e724c8d218682f00e49328a173                 31  LOCATION_SUMMARY
# 2613  fecaa6e724c8d218682f00e49328a173                 32  LOCATION_SUMMARY
# 2614  fecaa6e724c8d218682f00e49328a173                 33  LOCATION_SUMMARY
# 2615  fecaa6e724c8d218682f00e49328a173                 36  LOCATION_SUMMARY
# 2616  fecaa6e724c8d218682f00e49328a173                 40  LOCATION_SUMMARY
# 2617  fecaa6e724c8d218682f00e49328a173                 41  LOCATION_SUMMARY
# 2618  fecaa6e724c8d218682f00e49328a173                 42  LOCATION_SUMMARY
# 2619  fecaa6e724c8d218682f00e49328a173                 43  LOCATION_SUMMARY
# 2620  fecaa6e724c8d218682f00e49328a173                 44  LOCATION_SUMMARY
# 2621  fecaa6e724c8d218682f00e49328a173                 45  LOCATION_SUMMARY
# 2622  fecaa6e724c8d218682f00e49328a173                 46  LOCATION_SUMMARY
# ...                                ...                ...               ...
# 3064  fecaa6e724c8d218682f00e49328a173                799  LOCATION_SUMMARY
# 3065  fecaa6e724c8d218682f00e49328a173                800  LOCATION_SUMMARY
# 3066  fecaa6e724c8d218682f00e49328a173                801  LOCATION_SUMMARY
# 3067  fecaa6e724c8d218682f00e49328a173                803  LOCATION_SUMMARY
# 3068  fecaa6e724c8d218682f00e49328a173                804  LOCATION_SUMMARY
# 3069  fecaa6e724c8d218682f00e49328a173                805  LOCATION_SUMMARY
# 3070  fecaa6e724c8d218682f00e49328a173                806  LOCATION_SUMMARY
# 3071  fecaa6e724c8d218682f00e49328a173                807  LOCATION_SUMMARY
# 3072  fecaa6e724c8d218682f00e49328a173                808  LOCATION_SUMMARY
# 3073  fecaa6e724c8d218682f00e49328a173                809  LOCATION_SUMMARY
# 3074  fecaa6e724c8d218682f00e49328a173                810  LOCATION_SUMMARY
# 3075  fecaa6e724c8d218682f00e49328a173                811  LOCATION_SUMMARY
# 3076  fecaa6e724c8d218682f00e49328a173                812  LOCATION_SUMMARY
# 3077  fecaa6e724c8d218682f00e49328a173                813  LOCATION_SUMMARY
# 3078  fecaa6e724c8d218682f00e49328a173                814  LOCATION_SUMMARY
# 3079  fecaa6e724c8d218682f00e49328a173                815  LOCATION_SUMMARY
# 3080  fecaa6e724c8d218682f00e49328a173                816  LOCATION_SUMMARY
# 3081  fecaa6e724c8d218682f00e49328a173                817  LOCATION_SUMMARY
# 3082  fecaa6e724c8d218682f00e49328a173                818  LOCATION_SUMMARY
# 3083  fecaa6e724c8d218682f00e49328a173                819  LOCATION_SUMMARY
# 3084  fecaa6e724c8d218682f00e49328a173                820  LOCATION_SUMMARY
# 3085  fecaa6e724c8d218682f00e49328a173                821  LOCATION_SUMMARY
# 3086  fecaa6e724c8d218682f00e49328a173                823  LOCATION_SUMMARY
# 3087  fecaa6e724c8d218682f00e49328a173                825  LOCATION_SUMMARY
# 3088  fecaa6e724c8d218682f00e49328a173                826  LOCATION_SUMMARY
# 3089  fecaa6e724c8d218682f00e49328a173                827  LOCATION_SUMMARY
# 3090  fecaa6e724c8d218682f00e49328a173                828  LOCATION_SUMMARY
# 3091  fecaa6e724c8d218682f00e49328a173                829  LOCATION_SUMMARY
# 3092  fecaa6e724c8d218682f00e49328a173                830  LOCATION_SUMMARY
# 3093  fecaa6e724c8d218682f00e49328a173                831  LOCATION_SUMMARY
#
#                                               placeIqId  dmaName
# 2593  AutomotiveDealerships->Domestic->General->GMC-...      515
# 2594  AutomotiveDealerships->Domestic->Luxury->GMC->...      515
# 2595  AutomotiveDealerships->Domestic->General->GMC-...      515
# 2596  AutomotiveDealerships->Domestic->General->Fiat...      515
# 2597  AutomotiveDealerships->Domestic->General->Fiat...      515
# 2598  AutomotiveDealerships->Domestic->General->Ford...      515
# 2599  AutomotiveDealerships->Domestic->General->GMC-...      515
# 2600  AutomotiveDealerships->Domestic->General->Fiat...      515
# 2601  AutomotiveDealerships->Domestic->Luxury->Ford-...      515
# 2602  AutomotiveDealerships->Domestic->General->Fiat...      515
# 2603  AutomotiveDealerships->Foreign->Luxury->Honda-...      515
# 2604   AutomotiveDealerships->Foreign->Luxury->BMW->BMW      515
# 2605  AutomotiveDealerships->Foreign->General->Honda...      515
# 2606  AutomotiveDealerships->Foreign->General->Hyund...      515
# 2607  AutomotiveDealerships->Foreign->Luxury->Volksw...      515
# 2608  AutomotiveDealerships->Foreign->General->Mazda...      515
# 2609  AutomotiveDealerships->Foreign->Luxury->Daimle...      515
# 2610  AutomotiveDealerships->Foreign->General->Mitsu...      515
# 2611  AutomotiveDealerships->Foreign->General->Nissa...      515
# 2612  AutomotiveDealerships->Foreign->Luxury->Volksw...      515
# 2613  AutomotiveDealerships->Foreign->General->Subar...      515
# 2614  AutomotiveDealerships->Foreign->General->Toyot...      515
# 2615              AutomotiveDealerships->HarleyDavidson      515
# 2616                            Demographic->Age->18_20      515
# 2617                            Demographic->Age->18_24      515
# 2618                            Demographic->Age->21_24      515
# 2619                            Demographic->Age->25_34      515
# 2620                            Demographic->Age->35_44      515
# 2621                            Demographic->Age->45_54      515
# 2622                            Demographic->Age->55_64      515
# ...                                                 ...      ...
# 3064  Retail->AutoPartsStoresandServiceCenters->Auto...      515
# 3065                               Retail->BigBoxStores      515
# 3066                        Retail->CellularPhoneStores      515
# 3067                          Retail->ConvenienceStores      515
# 3068                           Retail->DepartmentStores      515
# 3069                             Retail->DiscountStores      515
# 3070                          Retail->ElectronicsStores      515
# 3071                                    Retail->Errands      515
# 3072                            Retail->FurnitureStores      515
# 3073                                Retail->GasStations      515
# 3074                              Retail->GeneralStores      515
# 3075                          Retail->GolfStoreShoppers      515
# 3076                              Retail->GroceryStores      515
# 3077                             Retail->HardwareStores      515
# 3078                            Retail->HomeGoodsStores      515
# 3079                        Retail->LiquorStoreShoppers      515
# 3080                                     Retail->Luxury      515
# 3081                                      Retail->Malls      515
# 3082                         Retail->OfficeSupplyStores      515
# 3083                                Retail->OutletMalls      515
# 3084                                  Retail->PetStores      515
# 3085                                 Retail->Pharmacies      515
# 3086                                  Retail->ToyStores      515
# 3087                             Travel->BusinessTravel      515
# 3088                         Travel->CommercialAirports      515
# 3089                        Travel->CostConsciousHotels      515
# 3090                                     Travel->Hotels      515
# 3091                             Travel->Hotels->Luxury      515
# 3092                            Travel->Hotels->Premium      515
# 3093                        Travel->TouristDestinations      515
#
# [501 rows x 8 columns]

# %%
isOneToOne(location_audience_data, 'locationHash', 'uniqueDevicesAtLocation')
# Out:
# False

# %%
locH_to_uniqueDevicesAtLocation = location_audience_data[['locationHash','uniqueDevicesAtLocation']]
locH_to_uniqueDevicesAtLocation
# Out:
#                            locationHash  uniqueDevicesAtLocation
# 0      b6e71c034fa5e34b5d8a9199208d53cb                      366
# 1      b6e71c034fa5e34b5d8a9199208d53cb                      366
# 2      b6e71c034fa5e34b5d8a9199208d53cb                      366
# 3      b6e71c034fa5e34b5d8a9199208d53cb                      366
# 4      b6e71c034fa5e34b5d8a9199208d53cb                      366
# 5      b6e71c034fa5e34b5d8a9199208d53cb                      366
# 6      b6e71c034fa5e34b5d8a9199208d53cb                      366
# 7      b6e71c034fa5e34b5d8a9199208d53cb                      366
# 8      b6e71c034fa5e34b5d8a9199208d53cb                      366
# 9      b6e71c034fa5e34b5d8a9199208d53cb                      366
# 10     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 11     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 12     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 13     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 14     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 15     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 16     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 17     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 18     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 19     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 20     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 21     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 22     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 23     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 24     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 25     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 26     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 27     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 28     b6e71c034fa5e34b5d8a9199208d53cb                      366
# 29     b6e71c034fa5e34b5d8a9199208d53cb                      366
# ...                                 ...                      ...
# 19964  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19965  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19966  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19967  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19968  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19969  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19970  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19971  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19972  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19973  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19974  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19975  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19976  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19977  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19978  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19979  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19980  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19981  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19982  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19983  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19984  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19985  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19986  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19987  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19988  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19989  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19990  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19991  0c89d6c44290bc885650a2eb4a3f480e                      215
# 19992  0c89d6c44290bc885650a2eb4a3f480e                      215
# 19993  0c89d6c44290bc885650a2eb4a3f480e                      215
#
# [19994 rows x 2 columns]

# %%
locH_to_uniqueDevicesAtLocation = locH_to_uniqueDevicesAtLocation.drop_duplicates()
locH_to_uniqueDevicesAtLocation
# Out:
#                            locationHash  uniqueDevicesAtLocation
# 0      b6e71c034fa5e34b5d8a9199208d53cb                      366
# 420    b14273d2a9fb0465d2fe6a1d859e5b6d                    14129
# 1153   f9fe2a60466142fc3666e5e20e4ca701                      828
# 1678   3fa83a49e380c72cd6be15b29ac6e53d                      211
# 1975   5a1308e5465bfe32d67b8171ec5a1a58                     2823
# 2593   fecaa6e724c8d218682f00e49328a173                      899
# 3094   4189a97e0a61cab5a19862910f6a555e                   279443
# 3896   b1b16e79fd5cad106899df827e3d9d12                      110
# 4210   b03a84f7ee3b2c4546e774cd36e762db                    24081
# 4991   9a74a7e8192188f478b3bd3b1f887a03                      294
# 5321   8e068a53d42717b05eb8ae317590165f                    31610
# 6129   56b704d2f77094c89a85d170b972b449                     3928
# 6778   387cc3a3376bedf0388698a3715ee137                    36855
# 7514   88cd97c420635430a6014b672d5c67b6                     1363
# 8088   ce68239ed83c6c1d85707fe8319a8917                     1828
# 8666   c8c505947fa572674fe920e201da1e3f                     3507
# 9327   c3daa24315511ad4bbbce3d3be687908                      288
# 9647   13151ff83caabeeecf14ee69512f70d3                     2526
# 10270  84f6050da3b919f5f742e8d5d787a264                    10926
# 11024  93afb61aab2c5b09107ebc0a8c1f6fac                     1214
# 11557  56795ff9c9d5378b4ead68c31833a406                     4779
# 12265  5ae370d6b68926236ba7b659dbbbf251                     2114
# 12866  c976d31ec7c1077481faa28693517ebc                    16917
# 13662  2a3180b90180b227db81c95b49240bd2                     1053
# 14221  cbd209a58f1613278732ae88afa25c79                       62
# 14381  e46630e498e76d2e04f2ed521f4ae35e                    55503
# 15107  95d58fb689c6dbc1a71d44dcaf43aa46                      548
# 15516  892ed24d6fe6b03e61e6dd441d650fac                      268
# 15912  e139955e52f449d931cacbc773950d95                      263
# 16280  60334adaae82a1a172c3c1020dee7b07                     3095
# 17000  5de857121848bc3caa0adfed05dbe3ae                     1467
# 17532  19948cf2ef652334cc2d7f4609eb1f28                     1999
# 18165  2ecabc7a18e9332b10bad28e75167544                     3052
# 18763  8237da911b3dc385276efc93b19ecaad                     2418
# 19352  f4a2fe3a4cc1389495d39501f88f1153                     1379
# 19991  0c89d6c44290bc885650a2eb4a3f480e                      215

# %%
# inner join
df_merged = pd.merge(locH_to_uniqueDevicesAtLocation, billboards_data, on='locationHash')
df_merged.head(10)
# Out:
#                        locationHash  uniqueDevicesAtLocation     id  \
# 0  b6e71c034fa5e34b5d8a9199208d53cb                      366  13194
# 1  b14273d2a9fb0465d2fe6a1d859e5b6d                    14129  84106
# 2  b14273d2a9fb0465d2fe6a1d859e5b6d                    14129  90605
# 3  f9fe2a60466142fc3666e5e20e4ca701                      828  49413
# 4  3fa83a49e380c72cd6be15b29ac6e53d                      211  48569
# 5  5a1308e5465bfe32d67b8171ec5a1a58                     2823  24530
# 6  fecaa6e724c8d218682f00e49328a173                      899  44235
# 7  4189a97e0a61cab5a19862910f6a555e                   279443  12476
# 8  4189a97e0a61cab5a19862910f6a555e                   279443  66539
# 9  b1b16e79fd5cad106899df827e3d9d12                      110  92361
#
#    networkId                                               name directionId  \
# 0      13062                                            DUCKIES           0
# 1      75538                  Physician's office - waiting room           0
# 2      75538                  Physician's office - waiting room           0
# 3      13066                                     ROCCO & ANNA'S           0
# 4      13066                                       CENTRAL HOSE           0
# 5      13066                  ADDISON'S STEAKHOUSE & SPORTS BAR           0
# 6      13066                       SUM PLACE ELSE BAR AND GRILL           0
# 7          0                              40.116476, -75.260183          10
# 8      65275  I-276 PA Turnpike South Side 2060ft East Of Bu...          10
# 9      75538                  Physician's office - waiting room           0
#
#   directionName          lat        lng        googlePlacesId  typeId  \
# 0           NaN  33.65812000 -86.724140        Birmingham, AL   164.0
# 1           NaN      30.5196 -87.888670          Fairhope, AL   171.0
# 2           NaN      30.5196 -87.888670          Fairhope, AL   171.0
# 3           NaN  39.96099000 -75.917860        Parkesburg, PA   164.0
# 4           NaN  41.49682000 -78.683950       Johnsonburg, PA   164.0
# 5           NaN  42.33246000 -88.275320           McHenry, IL   164.0
# 6           NaN  39.18637000 -83.933490      Fayetteville, OH   164.0
# 7          East  40.11647600 -75.260183                   NaN    75.0
# 8          East  40.11647600 -75.260183  Plymouth Meeting, PA    75.0
# 9           NaN      40.5593 -80.154200         Sewickley, PA   171.0
#
#                       typeName
# 0       Bar/Restaurant Jukebox
# 1  Doctors Office Waiting Room
# 2  Doctors Office Waiting Room
# 3       Bar/Restaurant Jukebox
# 4       Bar/Restaurant Jukebox
# 5       Bar/Restaurant Jukebox
# 6       Bar/Restaurant Jukebox
# 7                     Bulletin
# 8                     Bulletin
# 9  Doctors Office Waiting Room

# %%
# NG!? sum()??
grouped_by_typeName_and_locH = df_merged.groupby(['typeName','typeId','locationHash'])['uniqueDevicesAtLocation'].sum().unstack()
print(type(grouped_by_typeName_and_locH))
grouped_by_typeName_and_locH
# Since the location_audience_data is partial data, some of the typeName are deleted when inner joined.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# locationHash                        0c89d6c44290bc885650a2eb4a3f480e  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                              215.0
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        13151ff83caabeeecf14ee69512f70d3  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                                NaN
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                             2526.0
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        19948cf2ef652334cc2d7f4609eb1f28  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                                NaN
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                             1999.0
#
# locationHash                        2a3180b90180b227db81c95b49240bd2  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                                NaN
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                             1053.0
#
# locationHash                        2ecabc7a18e9332b10bad28e75167544  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                             3052.0
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        387cc3a3376bedf0388698a3715ee137  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                                NaN
# Bulletin                    75.0                             36855.0
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        3fa83a49e380c72cd6be15b29ac6e53d  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                              211.0
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        4189a97e0a61cab5a19862910f6a555e  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                                NaN
# Bulletin                    75.0                            558886.0
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        56795ff9c9d5378b4ead68c31833a406  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                                NaN
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                             4779.0
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        56b704d2f77094c89a85d170b972b449  ...  \
# typeName                    typeId                                    ...
# Bar/Restaurant Jukebox      164.0                             3928.0  ...
# Bulletin                    75.0                                 NaN  ...
# Doctors Office Waiting Room 171.0                                NaN  ...
# Point of Sale Screen        177.0                                NaN  ...
#
# locationHash                        c3daa24315511ad4bbbce3d3be687908  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                              288.0
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        c8c505947fa572674fe920e201da1e3f  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                             3507.0
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        c976d31ec7c1077481faa28693517ebc  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                            16917.0
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        cbd209a58f1613278732ae88afa25c79  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                               62.0
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        ce68239ed83c6c1d85707fe8319a8917  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                             1828.0
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        e139955e52f449d931cacbc773950d95  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                              263.0
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        e46630e498e76d2e04f2ed521f4ae35e  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                                NaN
# Bulletin                    75.0                             55503.0
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        f4a2fe3a4cc1389495d39501f88f1153  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                                NaN
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                             1379.0
#
# locationHash                        f9fe2a60466142fc3666e5e20e4ca701  \
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                              828.0
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# locationHash                        fecaa6e724c8d218682f00e49328a173
# typeName                    typeId
# Bar/Restaurant Jukebox      164.0                              899.0
# Bulletin                    75.0                                 NaN
# Doctors Office Waiting Room 171.0                                NaN
# Point of Sale Screen        177.0                                NaN
#
# [4 rows x 36 columns]

# %%
f = open("output_kei/location/output.txt", "w+")
for index, row in grouped_by_typeName_and_locH.iterrows():
    print(index[0], file=f)
    row = row.dropna()
    print(row.describe(), file=f)
    print("-----------------------------------", file=f)
#     removed_outlier = remove_outlier(value, 'count')
    plt.title("Histogram for Location Type: " + index[0])
    plt.hist(row, bins='auto')
    plt.xlabel('uniqueDevicesAtLocation')
    plt.ylabel('Frequency');
    plt.grid(True)
    plt.savefig("output_kei/location/histogram/location_type_" + str(int(index[1])) + ".png", bbox_inches='tight',dpi=100)
    plt.close()


f.close()
print('done.')
# Out:
# done.
